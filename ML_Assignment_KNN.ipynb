# %%
import pandas as pd             #importing essential libraries

# %%
url = 'https://github.com/sathvikbhupal1/MachineLearning/blob/main/MachineLearning_Datasets/sonar.all-data.csv?raw=true'
df = pd.read_csv(url)                         #importing the dataset from my github account and reading it through .read_csv function
df
# Out:
#      Freq_1  Freq_2  Freq_3  Freq_4  Freq_5  Freq_6  Freq_7  Freq_8  Freq_9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.info()                   #using .info() function to check for the null values and data types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Freq_1   208 non-null    float64
#  1   Freq_2   208 non-null    float64
#  2   Freq_3   208 non-null    float64
#  3   Freq_4   208 non-null    float64
#  4   Freq_5   208 non-null    float64
#  5   Freq_6   208 non-null    float64
#  6   Freq_7   208 non-null    float64
#  7   Freq_8   208 non-null    float64
#  8   Freq_9   208 non-null    float64
#  9   Freq_10  208 non-null    float64
#  10  Freq_11  208 non-null    float64
#  11  Freq_12  208 non-null    float64
#  12  Freq_13  208 non-null    float64
#  13  Freq_14  208 non-null    float64
#  14  Freq_15  208 non-null    float64
#  15  Freq_16  208 non-null    float64
#  16  Freq_17  208 non-null    float64
#  17  Freq_18  208 non-null    float64
#  18  Freq_19  208 non-null    float64
#  19  Freq_20  208 non-null    float64
# ...

# %%
df.shape                      #checking dataframe's total number of rows & columns
# Out:
# (208, 61)

# %%
df.isnull().sum()              #calculating the null values in the df
# Out:
# Freq_1     0
# Freq_2     0
# Freq_3     0
# Freq_4     0
# Freq_5     0
#           ..
# Freq_57    0
# Freq_58    0
# Freq_59    0
# Freq_60    0
# Label      0
# Length: 61, dtype: int64

# %%
import seaborn as sn              #importing essential library

# %%
sn.countplot(data=df,x='Label')               #plotting a bar graph of value count on the Label column

# %%
df.columns                            #checking the number of columns and column names
# Out:
# Index(['Freq_1', 'Freq_2', 'Freq_3', 'Freq_4', 'Freq_5', 'Freq_6', 'Freq_7',
#        'Freq_8', 'Freq_9', 'Freq_10', 'Freq_11', 'Freq_12', 'Freq_13',
#        'Freq_14', 'Freq_15', 'Freq_16', 'Freq_17', 'Freq_18', 'Freq_19',
#        'Freq_20', 'Freq_21', 'Freq_22', 'Freq_23', 'Freq_24', 'Freq_25',
#        'Freq_26', 'Freq_27', 'Freq_28', 'Freq_29', 'Freq_30', 'Freq_31',
#        'Freq_32', 'Freq_33', 'Freq_34', 'Freq_35', 'Freq_36', 'Freq_37',
#        'Freq_38', 'Freq_39', 'Freq_40', 'Freq_41', 'Freq_42', 'Freq_43',
#        'Freq_44', 'Freq_45', 'Freq_46', 'Freq_47', 'Freq_48', 'Freq_49',
#        'Freq_50', 'Freq_51', 'Freq_52', 'Freq_53', 'Freq_54', 'Freq_55',
#        'Freq_56', 'Freq_57', 'Freq_58', 'Freq_59', 'Freq_60', 'Label'],
#       dtype='object')

# %%
X = df.drop(columns=['Label'])                             #splitting the data into features (X) and target (Y) to train further
Y = df['Label']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler                #importing essential libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score,precision_score,f1_score,recall_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)             #splitting the data into train and test portions

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)                                  #standard scaler is used to deal with the outliers as data has extreme points
X_test=s.transform(X_test)

# %%
model=KNeighborsClassifier(n_neighbors=1)               #building K nearest neighbors model/classifier
model = model.fit(X_train, y_train)                      #applying the K nearest neighbors model to the training data


predictions = model.predict(X_test)                       #predicting using test_data on the basis of model performance on training data

print("Score:", round(model.score(X_test, y_test),2)*100 ,'%')  #checking the score by comparing the feature test data to target test data and compute accuracy
# Out:
# Score: 81.0 %

# %%
recall=recall_score(y_test,predictions, average="binary", pos_label="M")              #checking other metrics such as recall, precision, f1 score to evaluate the model
precision=precision_score(y_test,predictions, average="binary", pos_label="M")
f1=f1_score(y_test,predictions, average="binary", pos_label="M")

# %%
pd.DataFrame({'Model Metrics': [ recall, precision,f1]}, index=[ 'recall', 'precision','f1'])     #visualising the metrics in the form of df
# Out:
#            Model Metrics
# recall          0.904762
# precision       0.760000
# f1              0.826087
